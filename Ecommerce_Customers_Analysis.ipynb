# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as mg

# %%
ecommerce= pd.read_csv('Ecommerce Customers.csv')

# %%
ecommerce
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
# USING VISUALIZATION TO CHECK IF THEY ARE MISSING DATA:

mg.bar(ecommerce,color='green')
plt.show()

# %%
emails= ecommerce['Email']
gmail= []
yahoo= []
hotmail= []
com= []
net= []
biz= []
org= []
info= []
others= []

for mail in emails:
    if '@gmail.com' in mail:
        gmail.append(mail)
    elif '@yahoo.com' in mail:
        yahoo.append(mail)
    elif '@hotmail.com' in mail:
        hotmail.append(mail)
    elif '.com' in mail:
        com.append(mail)
    elif '.net' in mail:
        net.append(mail)
    elif '.biz' in mail:
        biz.append(mail)
    elif '.org' in mail:
        org.append(mail)
    elif '.info' in mail:
        info.append(mail)
    else:
        others.append(mail)

# %%
print(f'''
Numbers of gmail => {len(gmail)}
Numbers of yahoomail => {len(yahoo)}
Numbers of hotmail => {len(hotmail)}
Numbers of other Emails with .com => {len(com)}
Numbers of other Emails with .net => {len(net)}
Numbers of other Emails with .biz => {len(biz)}
Numbers of other Emails with .org => {len(org)}
Numbers of other Emails with .info => {len(info)}
''')
# Out:
# Numbers of gmail => 87
# Numbers of yahoomail => 76
# Numbers of hotmail => 87
# Numbers of other Emails with .com => 148
# Numbers of other Emails with .net => 31
# Numbers of other Emails with .biz => 23
# Numbers of other Emails with .org => 24
# Numbers of other Emails with .info => 24

# %%
# finding the highest and lowest yearly amount spent:
high= max(ecommerce['Yearly Amount Spent'])
low= min(ecommerce['Yearly Amount Spent'])

# %%
# The user with the highest yearly amount spent:
ecommerce[(ecommerce['Yearly Amount Spent']==high)]
# Out:
#              Email                                           Address  \
# 65  kyang@diaz.org  223 Love Trail Suite 831\nPort Jeffrey, IN 46849
#
#        Avatar  Avg. Session Length  Time on App  Time on Website  \
# 65  OliveDrab            34.374258    15.126994        37.157624
#
#     Length of Membership  Yearly Amount Spent
# 65              5.377594           765.518462

# %%
# The user with the lowest yearly amount spent:
ecommerce[(ecommerce['Yearly Amount Spent']==low)]
# Out:
#                              Email                                Address  \
# 225  alexandra26@summers-davis.com  Unit 7032 Box 7016\nDPO AE 44749-2992
#
#     Avatar  Avg. Session Length  Time on App  Time on Website  \
# 225   Navy            32.836941    10.256549        36.143908
#
#      Length of Membership  Yearly Amount Spent
# 225               0.78952           256.670582

# %%
# finding the highest and lowest Time on App:
high_TOA= max(ecommerce['Time on App'])
low_TOA= min(ecommerce['Time on App'])

# %%
# The user that spent more time on the app:
ecommerce[(ecommerce['Time on App']==high_TOA)]
# Out:
#              Email                                           Address  \
# 65  kyang@diaz.org  223 Love Trail Suite 831\nPort Jeffrey, IN 46849
#
#        Avatar  Avg. Session Length  Time on App  Time on Website  \
# 65  OliveDrab            34.374258    15.126994        37.157624
#
#     Length of Membership  Yearly Amount Spent
# 65              5.377594           765.518462

# %%
# The user that spent less time on the app:
ecommerce[(ecommerce['Time on App']==low_TOA)]
# Out:
#                 Email                                         Address  \
# 309  dblair@gmail.com  190 Kelley Burg\nWest Juliaport, IA 35826-8163
#
#               Avatar  Avg. Session Length  Time on App  Time on Website  \
# 309  MediumSlateBlue            34.102279     8.508152          35.4624
#
#      Length of Membership  Yearly Amount Spent
# 309              1.838211           302.189548

# %%
# finding the highest and lowest  Time on Website:
high_TOW= max(ecommerce['Time on Website'])
low_TOW= min(ecommerce['Time on Website'])

# %%
# The user that spent more time on the Website:
ecommerce[(ecommerce['Time on Website']==high_TOW)]
# Out:
#                           Email                                       Address  \
# 69  davisrobert@hicks-smith.com  95967 Pitts Burgs\nWest Sarah, MH 27817-5147
#
#      Avatar  Avg. Session Length  Time on App  Time on Website  \
# 69  SkyBlue              32.1791    11.187539        40.005182
#
#     Length of Membership  Yearly Amount Spent
# 69               3.55265           451.575685

# %%
# The user that spent less time on the Website:
ecommerce[(ecommerce['Time on Website']==low_TOW)]
# Out:
#                 Email                     Address Avatar  Avg. Session Length  \
# 157  asilva@yahoo.com  USNV Johnson\nFPO AP 19026  Wheat            34.603311
#
#      Time on App  Time on Website  Length of Membership  Yearly Amount Spent
# 157    12.207298        33.913847              6.922689           744.221867

# %%
# finding the highest and lowest  Length of Membership:
high_LOM= max(ecommerce['Length of Membership'])
low_LOM= min(ecommerce['Length of Membership'])

# %%
# The user with the highest length of membership:
ecommerce[(ecommerce['Length of Membership']==high_LOM)]
# Out:
#                 Email                     Address Avatar  Avg. Session Length  \
# 157  asilva@yahoo.com  USNV Johnson\nFPO AP 19026  Wheat            34.603311
#
#      Time on App  Time on Website  Length of Membership  Yearly Amount Spent
# 157    12.207298        33.913847              6.922689           744.221867

# %%
# The user with the lowest length of membership:
ecommerce[(ecommerce['Length of Membership']==low_LOM)]
# Out:
#                       Email  \
# 447  sharongraves@yahoo.com
#
#                                                Address Avatar  \
# 447  73098 Ronald Port\nCliffordborough, MO 37479-9244  Wheat
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 447            32.904854    12.556108        37.805509              0.269901
#
#      Yearly Amount Spent
# 447           314.438518

# %%
# finding the highest and lowest Avg. Session Length:
high_ASL= max(ecommerce['Avg. Session Length'])
low_ASL= min(ecommerce['Avg. Session Length'])

# %%
# The user with the highest Avg. Session Length:
ecommerce[(ecommerce['Avg. Session Length']==high_ASL)]
# Out:
#                     Email                                      Address  \
# 154  nathan86@hotmail.com  748 Michael Plaza\nWest Billyside, UT 20799
#
#            Avatar  Avg. Session Length  Time on App  Time on Website  \
# 154  MidnightBlue            36.139662    12.050267        36.959643
#
#      Length of Membership  Yearly Amount Spent
# 154              3.864861           595.803819

# %%
# The user with the lowest Avg. Session Length:
ecommerce[(ecommerce['Avg. Session Length']==low_ASL)]
# Out:
#                 Email                                            Address  \
# 12  knelson@gmail.com  6705 Miller Orchard Suite 186\nLake Shanestad,...
#
#        Avatar  Avg. Session Length  Time on App  Time on Website  \
# 12  RoyalBlue            29.532429    10.961298        37.420216
#
#     Length of Membership  Yearly Amount Spent
# 12              4.046423           408.640351

# %%
# Counting and finding the number of different Avatars:
no_ava= len(ecommerce['Avatar'].value_counts())
print(f'The Number Of Different Avatars => {no_ava}')
# Out:
# The Number Of Different Avatars => 138
